# %%
import os
import pandas as pd
print(os.listdir('/'))
df=pd.read_csv("Studentmarks.csv")
#print(df)
for i,col in enumerate(df.columns,start=1):
    print(i,':',col)
print(df.shape)#no of rows and columns
print(df.head())
print(df["roll no"].value_counts())
print(df["roll no"].isnull().sum())
print(df.duplicated().sum())
# Out:
# ['home', 'usr', '.resolve', 'bin', 'sbin', '.file', 'etc', 'var', 'Library', 'System', '.VolumeIcon.icns', 'private', '.vol', 'Users', 'Applications', 'opt', 'dev', 'Volumes', '.nofollow', 'tmp', 'cores']
# 1 : s.no
# 2 : roll no
# 3 : name
# 4 : marks
# 5 : pass
# (6, 5)
#    s.no     roll no     name  marks  pass
# 0     1  2520030408    jemmy      1   0.0
# 1     2  2520030412  Amrutha    100   1.0
# 2     3  2520080066  Amrutha      4   0.0
# 3     4  2520030171      anu     50   1.0
# 4     5  2520090042   chakki      0   0.0
# roll no
# 2520030408    1
# 2520030412    1
# 2520080066    1
# 2520030171    1
# 2520090042    1
# 2520030000    1
# Name: count, dtype: int64
# 0
# 0
